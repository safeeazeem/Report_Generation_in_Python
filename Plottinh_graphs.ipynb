# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#sns.set_palette('Blues')
#sns.color_palette("RdBu", n_colors=7)

#sns.set(style='darkgrid')

# %%
df = pd.read_csv('Marks.csv')

# %%
df.head()
# Out:
#      roll          name  age  year sec  dp  eng  math  sci  isl  ar   avg  \
# 0  123456  Safee Muhaha   36    10   B  56   67    89   98   76  67  79.4
# 1  123456  Rafay Muhaha   45    10   A  78   67    89   73   45  67  68.2
#
#                                              comment
# 0  He has been able to confidently discuss occasi...
# 1               He is an amazing boy with good brain

# %%
#Accessing dictionary values
df.iloc[0][6:11]
# Out:
# eng     67
# math    89
# sci     98
# isl     76
# ar      67
# Name: 0, dtype: object

# %%
# COnverting to dictionary
dfd = df.to_dict(orient='records')

# %%
dfd[0].get('eng')
# Out:
# 67

# %%
dfd[0]['name']
# Out:
# 'Safee Muhaha'

# %%
df.columns['eng']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-335-5c6cae2d0dca> in <module>
# ----> 1 df.columns['eng']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# from matplotlib import rcParams

plt.figure(figsize=(6,6))
fig = plt.figure()

# plt.style.use('seaborn-dark-palette')
ax = fig.add_axes([0,0,1,1])


x = ['English','Math','Science', 'Islamic','Arabic','Average']
y = [dfd[0].get('eng'),
     dfd[0].get('math'),
     dfd[0].get('sci'),
     dfd[0].get('isl'),
     dfd[0].get('ar'),
     dfd[0].get('avg')]

plt.xticks(fontsize = 20,rotation = 45)
plt.yticks(fontsize =20)
#plt.yticks(np.arange(0,100,5))
plt.ylim(0,100)
# plt.xlabel('Subjects',labelpad=10)
plt.ylabel('Percentage(%)',fontsize= 20,fontweight='bold')
plt.title("Student Performance",fontsize=40,pad=20,loc='center')

bars =ax.bar(x,y,width = 0.5,color='dodgerblue',align = 'center')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x()+.1, yval - 5,yval,fontsize=20,
             fontweight='bold',color = 'white')
    
plt.savefig('Student.jpeg',bbox_inches ='tight')
plt.show()
plt.close()
# Out:
# C:\Users\Safee\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# C:\Users\Safee\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2= len(pd.read_csv('Marks.csv'))
for i in range(0,df2):
    plt.figure(figsize=(6,6))
    fig = plt.figure()

    # plt.style.use('seaborn-dark-palette')
    ax = fig.add_axes([0,0,1,1])


    x = ['English','Math','Science', 'Islamic','Arabic','Average']
    y = [dfd[i].get('eng'),
         dfd[i].get('math'),
         dfd[i].get('sci'),
         dfd[i].get('isl'),
         dfd[i].get('ar'),
         dfd[i].get('avg')]

    plt.xticks(fontsize = 20,rotation = 45)
    plt.yticks(fontsize =20)
    #plt.yticks(np.arange(0,100,5))
    plt.ylim(0,100)
    # plt.xlabel('Subjects',labelpad=10)
    plt.ylabel('Percentage(%)',fontsize= 20,fontweight='bold')
    plt.title("Student Performance",fontsize=40,pad=20,loc='center')

    bars =ax.bar(x,y,width = 0.5,color='dodgerblue',align = 'center')

    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x()+.1, yval - 5,yval,fontsize=20,
                 fontweight='bold',color = 'white')
    
    plt.savefig('graph '+str(i)+".jpeg",bbox_inches ='tight')
    plt.show()
    plt.close()
# Out:
# C:\Users\Safee\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
df.head()
# Out:
#      roll          name  age  year sec  dp  eng  math  sci  isl  ar   avg  \
# 0  123456  Safee Muhaha   36    10   B  56   67    89   98   76  67  79.4
# 1  123456  Rafay Muhaha   45    10   A  78   67    89   73   45  67  68.2
#
#                                              comment
# 0  He has been able to confidently discuss occasi...
# 1               He is an amazing boy with good brain

# %%
df.columns[6:12]
# Out:
# Index(['eng', 'math', 'sci', 'isl', 'ar', 'avg'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-287-740c598c3beb> in <module>
# ----> 1 df(0)
#
# TypeError: 'DataFrame' object is not callable

# %%
plt.figure(figsize=(6,6))
fig = plt.figure()

# plt.style.use('seaborn-dark-palette')
ax = fig.add_axes([0,0,1,1])


x = ['English','Math','Science', 'Islamic','Arabic','Average']
#x=df.columns[6:12]
y = [dfd[0].get('eng'),
     dfd[0].get('math'),
     dfd[0].get('sci'),
     dfd[0].get('isl'),
     dfd[0].get('ar'),
     dfd[0].get('avg')]

plt.xticks(fontsize = 20,rotation = 45)
plt.yticks(fontsize =20)
#plt.yticks(np.arange(0,100,5))
plt.ylim(0,100)
# plt.xlabel('Subjects',labelpad=10)
plt.ylabel('Percentage(%)',fontsize= 20,fontweight='bold')
plt.title("Student Performance",fontsize=40,pad=20,loc='center')

# bars =ax.bar(x,y,width = 0.5,color='dodgerblue',align = 'center')
#plot = ax.scatter(x, y, marker='o',s=300)
plot=ax.plot(x, y, '-ok',);

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x()+.1, yval - 5,yval,fontsize=20,
             fontweight='bold',color = 'white')
    
plt.savefig('Student.jpeg',bbox_inches ='tight')
plt.show()
plt.close()
# Out:
# C:\Users\Safee\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
